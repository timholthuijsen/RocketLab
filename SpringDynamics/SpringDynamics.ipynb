# %% [markdown]
# $ m\ddot{x} = -b\dot{x} - kx $
#
#
# where m is the spacecraft mass in kg, b is the damping coefficient in Ns/m, k is the spring constant in N/m and x is the
# displacement of the spring in m

# %% [markdown]
# Hooke's law
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
